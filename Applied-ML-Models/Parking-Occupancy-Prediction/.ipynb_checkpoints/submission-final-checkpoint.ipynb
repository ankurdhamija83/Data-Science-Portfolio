# %% [markdown]
# # 1. Import and load the dataset

# %%
#Suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#Import the required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
import matplotlib.ticker as ticker

# %%
#Load the dataset
df = pd.read_csv('dataset/train.csv')

# %%
from ml_utils import *

# %% [markdown]
# # 2. Overview of the dataset

# %% [markdown]
# **Data Dictionary**
# - SystemCodeNumber: ID code for the parking area
# - Capacity: The number of parking spots available
# - ExitRate: Represents the exit rate of cars
# - FillRate: Represents the fill rate of cars
# - OccupancyPercentage: Represents the occupancy percentage
# - OccupancyTrend: Represents the trend in the car occupancy
# - Occupancy: The number of parkings spots actually occupied at the time
# - LastUpdated: The date and time of the observation

# %%
#Overview of the dataset
#Get an overview of the Dataset
df_overview(df, max_cat=20, figsize=(10,5))
# Out:
# **Shape of the Dataset:**
# (38034, 8)
# -----------------
# **Number of rows and columns in the Dataset:**
# Index(['SystemCodeNumber', 'Capacity', 'ExitRate', 'FillRate',
#        'OccupancyPercentage', 'OccupancyTrend', 'LastUpdated', 'Occupancy'],
#       dtype='object')
# -----------------
# **Basic information of the Dataset:**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38034 entries, 0 to 38033
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SystemCodeNumber     38034 non-null  object
#  1   Capacity             38034 non-null  int64
#  2   ExitRate             38034 non-null  float64
#  3   FillRate             38034 non-null  float64
#  4   OccupancyPercentage  38034 non-null  float64
#  5   OccupancyTrend       38034 non-null  object
#  6   LastUpdated          38034 non-null  object
#  7   Occupancy            38034 non-null  int64
# ...

# %% [markdown]
# **From an initial overview of the dataset, we summarize following points**
# - There are no missing values in the dataset
# - There are no duplicate rows in the dataset
# - OccupancyPercentage calculations seem to be incorrect
# - LastUpdated field should be a datetime (datetime64 in Pandas)

# %%
df["SystemCodeNumber"].value_counts()
# Out:
# BHMBCCMKT01         2624
# BHMBCCPST01         2281
# Others-CCCPS135a    1312
# Others-CCCPS202     1312
# Others-CCCPS98      1312
# BHMMBMMBX01         1312
# Shopping            1312
# BHMEURBRD01         1312
# Others-CCCPS105a    1312
# BHMBCCTHL01         1312
# Others-CCCPS8       1312
# Others-CCCPS119a    1312
# BHMNCPNST01         1312
# BHMNCPHST01         1312
# Broad Street        1312
# BHMBCCSNH01         1294
# Others-CCCPS133     1294
# BHMNCPLDH01         1292
# BHMNCPPLS01         1291
# BHMEURBRD02         1276
# NIA Car Parks       1204
# NIA South           1204
# BHMBRCBRG02         1186
# BHMBRCBRG01         1186
# BHMNCPRAN01         1186
# BHMBRCBRG03         1186
# Bull Ring           1186
# BHMNCPNHS01         1038
# NIA North            162
# BHMBRTARC01           88
# Name: SystemCodeNumber, dtype: int64

# %% [markdown]
# -------

# %% [markdown]
# # 3. Data Cleaning

# %% [markdown]
# ### Key date cleaning steps perfomed
# - Change `LastUpdated` from `string` to a `datetime` type.
# - Remove `whitespace` from `SystemCodeNumber` and `OccupancyTrend` columns
# - Drop `ExitRate` and `FillRate` columns
# - Drop `OccupancyTrend` column
# - Remove rows wherein value of `Occupancy > Capacity`. It could be a typing error or sensor measurement error.
# - Update calculation of `OccupancyPercentage` column as the values are incorrect
# - Remove `7:30 am timestamps` as we only have 30 values for it
# - Create `new date/time` related `columns`
# - Check and remove `duplicate values` in the dataset

# %%
def dataCleaning(df):
    
    #Convert LastUpdated from string to datetime object
    df["LastUpdated"] = pd.to_datetime(df["LastUpdated"])
    
    # Select categorical columns
    catCols = df.select_dtypes("object").columns
    
    # Remove whitespace from categorical columns
    for col in catCols:

        # applying strip function on column
        df[col] = df[col].map(str.strip)
        
    #Drop ExitRate and FillRate
    df = drop_col(df,["ExitRate","FillRate"])
    
    #Drop OccupancyTrend
    df = drop_col(df,["OccupancyTrend"])
    
    # Create new columns extracting information from the LastUpdated column - 
    # month, week, dayofweek, date, date_time_halfhour and time
    df['month'] = df.LastUpdated.dt.month
    df['week'] = df.LastUpdated.dt.week
    df['dayofweek'] = df.LastUpdated.dt.dayofweek
    df['date'] = df.LastUpdated.dt.date
    df['date_time_halfhour'] = df.LastUpdated.dt.round('30min')
    df['time'] = df.date_time_halfhour.dt.time
    
    return df

# %%
df.head()
# Out:
#   SystemCodeNumber  Capacity  ExitRate  FillRate  OccupancyPercentage  \
# 0      BHMBCCMKT01       577      2.09      2.18                 24.0
# 1      BHMBCCMKT01       577      3.60      0.13                  3.0
# 2      BHMBCCMKT01       577      0.00      2.75                 56.0
# 3      BHMBCCMKT01       577      1.51      2.18                 72.0
# 4      BHMBCCMKT01       577      0.73      2.10                  0.0
#
#   OccupancyTrend          LastUpdated  Occupancy
# 0         Faulty  2016-10-04 07:59:42         61
# 1         Static  2016-10-04 08:25:42         64
# 2       Emptying  2016-10-04 08:59:42         80
# 3         Faulty  2016-10-04 09:32:46        107
# 4         Faulty  2016-10-04 09:59:48        150

# %% [markdown]
# **3.1 Update LastUpdated column Data Type**

# %%
#Convert LastUpdated from string to datetime object
df["LastUpdated"] = pd.to_datetime(df["LastUpdated"])

# %% [markdown]
# **3.1 Remove whitespace from object columns**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38034 entries, 0 to 38033
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SystemCodeNumber     38034 non-null  object
#  1   Capacity             38034 non-null  int64
#  2   ExitRate             38034 non-null  float64
#  3   FillRate             38034 non-null  float64
#  4   OccupancyPercentage  38034 non-null  float64
#  5   OccupancyTrend       38034 non-null  object
#  6   LastUpdated          38034 non-null  datetime64[ns]
#  7   Occupancy            38034 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(2)
# memory usage: 2.3+ MB

# %%
# Select categorical columns
catCols = df.select_dtypes("object").columns

# %%
# Remove whitespace from categorical columns
for col in catCols:

    # applying strip function on column
    df[col] = df[col].map(str.strip)

# %% [markdown]
# **3.2 Drop ExitRate and FillRate columns**

# %% [markdown]
# We Drop `ExitRate` and `FillRate` columns as we don't have sufficient information on the columns as per the data dictionary.<br>
#
# - As per the data dictionary, we understand
#     - ExitRate - Represents the exit rate of cars
#     - FillRate - Represents the fill rate of cars
#
# - We can't use this data as we don't know the unit of rate of change, whether it is rate per 10 minutes/15 minutes etc.
# <br>
# Since, we don't have sufficient information on the columns ExitRate and FillRate, we drop both the columns.

# %%
#Drop ExitRate and FillRate
df = drop_col(df,["ExitRate","FillRate"])

# %% [markdown]
# **3.3 Drop OccupancyTrend Column**

# %% [markdown]
# We Drop `OccupancyTrend` column as we don't have sufficient information on the columns as per the data dictionary.

# %%
#Drop OccupancyTrend
df = drop_col(df,["OccupancyTrend"])

# %% [markdown]
# **3.4 Check the values in Occcupancy should always be less than or equal to Capacity**

# %%
# Check the range of OccupancyPercentage - should be between 0% and 100%
print('Minimum Percent Occupied: {:.2%}'.format(df["OccupancyPercentage"].min()))
print('Maximum Percent Occupied: {:.2%}'.format(df["OccupancyPercentage"].max()))
# Out:
# Minimum Percent Occupied: 0.00%
# Maximum Percent Occupied: 12740.00%

# %% [markdown]
# As the actual OccupancyPercentage goes upto 12,740%, it seems like there is a potential error in the Occupancy field and also in OccupancyPercentage calculations.
#
# - Drop rows from the dataframe wherein Occupancy > Capacity
# - Update OccupancyPercentage column with correct calculations

# %%
#Look for potential incorrect values in Occupancy Column
df = df[~(df["Occupancy"] > df["Capacity"])]

# %%
#Check if we still have Occupancy values > Capacity values
df[df["Occupancy"] > df["Capacity"]]
# Out:
# Empty DataFrame
# Columns: [SystemCodeNumber, Capacity, OccupancyPercentage, LastUpdated, Occupancy]
# Index: []

# %% [markdown]
# **3.5 Update OccupancyPercentage field as the calculations look incorrect**

# %%
df['OccupancyPercentage'] = df["Occupancy"] / df["Capacity"]

# %%
# Re-check range
print('Minimum Percent Occupied: {:.2%}'.format(df["OccupancyPercentage"].min()))
print('Maximum Percent Occupied: {:.2%}'.format(df["OccupancyPercentage"].max()))
# Out:
# Minimum Percent Occupied: -1.67%
# Maximum Percent Occupied: 100.00%

# %%
# Rows wherein OccupancyPercentage < 0
df[df["OccupancyPercentage"] < 0]
# Out:
#       SystemCodeNumber  Capacity  OccupancyPercentage         LastUpdated  \
# 23889        NIA North       480            -0.006250 2016-10-16 15:57:16
# 23890        NIA North       480            -0.006250 2016-10-16 16:31:17
# 23906        NIA North       480            -0.002083 2016-10-18 15:27:59
# 23919        NIA North       480            -0.016667 2016-10-28 13:02:43
# 23924        NIA North       480            -0.002083 2016-10-28 15:29:41
# 23925        NIA North       480            -0.008333 2016-10-28 16:02:40
# 23926        NIA North       480            -0.002083 2016-10-28 16:29:42
# 23937        NIA North       480            -0.004167 2016-10-29 12:59:51
# 23944        NIA North       480            -0.002083 2016-10-29 16:26:53
# 23997        NIA North       480            -0.006250 2016-11-10 16:00:15
# 24032        NIA North       480            -0.002083 2016-11-30 15:28:40
# 24033        NIA North       480            -0.004167 2016-11-30 16:01:39
#
# ...

# %%
# Remove rows wherein OccupancyPercentage < 0
df = df[df["OccupancyPercentage"] >= 0]

# %%
df.head()
# Out:
#   SystemCodeNumber  Capacity  OccupancyPercentage         LastUpdated  \
# 0      BHMBCCMKT01       577             0.105719 2016-10-04 07:59:42
# 1      BHMBCCMKT01       577             0.110919 2016-10-04 08:25:42
# 2      BHMBCCMKT01       577             0.138648 2016-10-04 08:59:42
# 3      BHMBCCMKT01       577             0.185442 2016-10-04 09:32:46
# 4      BHMBCCMKT01       577             0.259965 2016-10-04 09:59:48
#
#    Occupancy
# 0         61
# 1         64
# 2         80
# 3        107
# 4        150

# %% [markdown]
# **3.6 Check whether we have the correct timestamps in the dataset**

# %%
df.groupby(df["LastUpdated"].dt.hour)["LastUpdated"].count()
# Out:
# LastUpdated
# 7      833
# 8     4287
# 9     4301
# 10    4084
# 11    4201
# 12    4041
# 13    4306
# 14    4133
# 15    4167
# 16    3256
# Name: LastUpdated, dtype: int64

# %% [markdown]
# **3.7 Create new columns for date time details**

# %%
# Create new columns extracting information from the LastUpdated column - 
# month, week, dayofweek, date, date_time_halfhour and time
df['month'] = df.LastUpdated.dt.month
df['week'] = df.LastUpdated.dt.week
df['dayofweek'] = df.LastUpdated.dt.dayofweek
df['date'] = df.LastUpdated.dt.date
df['date_time_halfhour'] = df.LastUpdated.dt.round('30min')
df['time'] = df.date_time_halfhour.dt.time

# %% [markdown]
# Let's look at the time stamps in the dataset for which we have parking details

# %%
df.groupby(["time"]).size()
# Out:
# time
# 07:30:00      30
# 08:00:00    2230
# 08:30:00    2105
# 09:00:00    2085
# 09:30:00    2115
# 10:00:00    2117
# 10:30:00    2112
# 11:00:00    2083
# 11:30:00    2099
# 12:00:00    2074
# 12:30:00    2071
# 13:00:00    2067
# 13:30:00    2047
# 14:00:00    2074
# 14:30:00    2088
# 15:00:00    2087
# 15:30:00    2096
# 16:00:00    2075
# 16:30:00    1954
# dtype: int64

# %% [markdown]
# We see that we have only 30 entries for 07:30 am which we will discard.

# %%
df[df.time == datetime.time(7,30)]
# Out:
#       SystemCodeNumber  Capacity  OccupancyPercentage         LastUpdated  \
# 5374       BHMBRCBRG01      1010             0.216832 2016-10-23 07:32:50
# 5626       BHMBRCBRG01      1010             0.214851 2016-11-06 07:40:45
# 6668       BHMBRCBRG02      1194             0.034338 2016-10-29 07:39:45
# 15920      BHMNCPNHS01       500             0.210000 2016-11-19 07:37:12
# 16350      BHMNCPNHS01       500             0.312000 2016-12-18 07:43:20
# 17192      BHMNCPNST01       485             0.443299 2016-11-20 07:41:21
# 17336      BHMNCPNST01       485             0.397938 2016-11-28 07:42:26
# 17337      BHMNCPNST01       485             0.397938 2016-11-28 07:42:26
# 17338      BHMNCPNST01       485             0.397938 2016-11-28 07:42:26
# 17339      BHMNCPNST01       485             0.397938 2016-11-28 07:42:26
# 17340      BHMNCPNST01       485             0.397938 2016-11-28 07:42:26
# 17604      BHMNCPNST01       485             0.420619 2016-12-15 07:43:02
# ...

# %%
# filter out few 7:30 measurements
df = df[df.time > datetime.time(7,30)]

# %%
df.groupby(["time"]).size()
# Out:
# time
# 08:00:00    2230
# 08:30:00    2105
# 09:00:00    2085
# 09:30:00    2115
# 10:00:00    2117
# 10:30:00    2112
# 11:00:00    2083
# 11:30:00    2099
# 12:00:00    2074
# 12:30:00    2071
# 13:00:00    2067
# 13:30:00    2047
# 14:00:00    2074
# 14:30:00    2088
# 15:00:00    2087
# 15:30:00    2096
# 16:00:00    2075
# 16:30:00    1954
# dtype: int64

# %%
df.head()
# Out:
#   SystemCodeNumber  Capacity  OccupancyPercentage         LastUpdated  \
# 0      BHMBCCMKT01       577             0.105719 2016-10-04 07:59:42
# 1      BHMBCCMKT01       577             0.110919 2016-10-04 08:25:42
# 2      BHMBCCMKT01       577             0.138648 2016-10-04 08:59:42
# 3      BHMBCCMKT01       577             0.185442 2016-10-04 09:32:46
# 4      BHMBCCMKT01       577             0.259965 2016-10-04 09:59:48
#
#    Occupancy  month  week  dayofweek        date  date_time_halfhour      time
# 0         61     10    40          1  2016-10-04 2016-10-04 08:00:00  08:00:00
# 1         64     10    40          1  2016-10-04 2016-10-04 08:30:00  08:30:00
# 2         80     10    40          1  2016-10-04 2016-10-04 09:00:00  09:00:00
# 3        107     10    40          1  2016-10-04 2016-10-04 09:30:00  09:30:00
# 4        150     10    40          1  2016-10-04 2016-10-04 10:00:00  10:00:00

# %% [markdown]
# **3.8 Check for duplicate entries in the dataset again as we have remove few columns**

# %%
#Total number of duplicate rows
print(df.duplicated().sum())
# Out:
# 207

# %%
#View duplicate rows
df[df.duplicated()]
# Out:
#       SystemCodeNumber  Capacity  OccupancyPercentage         LastUpdated  \
# 397        BHMBCCMKT01       577             0.098787 2016-10-28 08:16:41
# 433        BHMBCCMKT01       577             0.074523 2016-10-30 07:59:55
# 434        BHMBCCMKT01       577             0.074523 2016-10-30 07:59:55
# 775        BHMBCCMKT01       577             0.060659 2016-11-18 08:01:05
# 901        BHMBCCMKT01       577             0.076256 2016-11-25 08:00:57
# ...                ...       ...                  ...                 ...
# 34802         Shopping      1920             0.291146 2016-10-28 08:16:41
# 34838         Shopping      1920             0.143229 2016-10-30 07:59:55
# 34839         Shopping      1920             0.143229 2016-10-30 07:59:55
# 35180         Shopping      1920             0.308333 2016-11-18 08:01:05
# 35306         Shopping      1920             0.309375 2016-11-25 08:00:57
#
#        Occupancy  month  week  dayofweek        date  date_time_halfhour  \
# ...

# %%
#Drop duplicate rows
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## 4. EDA

# %%
df.head()
# Out:
#   SystemCodeNumber  Capacity  OccupancyPercentage         LastUpdated  \
# 0      BHMBCCMKT01       577             0.105719 2016-10-04 07:59:42
# 1      BHMBCCMKT01       577             0.110919 2016-10-04 08:25:42
# 2      BHMBCCMKT01       577             0.138648 2016-10-04 08:59:42
# 3      BHMBCCMKT01       577             0.185442 2016-10-04 09:32:46
# 4      BHMBCCMKT01       577             0.259965 2016-10-04 09:59:48
#
#    Occupancy  month  week  dayofweek        date  date_time_halfhour      time
# 0         61     10    40          1  2016-10-04 2016-10-04 08:00:00  08:00:00
# 1         64     10    40          1  2016-10-04 2016-10-04 08:30:00  08:30:00
# 2         80     10    40          1  2016-10-04 2016-10-04 09:00:00  09:00:00
# 3        107     10    40          1  2016-10-04 2016-10-04 09:30:00  09:30:00
# 4        150     10    40          1  2016-10-04 2016-10-04 10:00:00  10:00:00

# %% [markdown]
# **Average Occupancy by month**

# %%
#View Average occupancy by month
res = df.groupby(["month"])["OccupancyPercentage"].mean()
print(res)
# Out:
# month
# 1     0.071433
# 2     0.086949
# 3     0.081810
# 4     0.080449
# 10    0.470763
# 11    0.485307
# 12    0.517246
# Name: OccupancyPercentage, dtype: float64

# %%
sns.lineplot(x=res.index, y=res, sort=False)
plt.title("Average Occupancy Percentage across Parking Lots by Month")
# Out:
# Text(0.5, 1.0, 'Average Occupancy Percentage across Parking Lots by Month')

# %% [markdown]
# **Average Occupancy by week**

# %%
#View Average occupancy by week
res = df.groupby(["week"])["OccupancyPercentage"].mean()
print(res)
# Out:
# week
# 1     0.099200
# 2     0.069878
# 3     0.060568
# 4     0.061813
# 5     0.077554
# 6     0.088863
# 7     0.084464
# 8     0.087948
# 9     0.088392
# 10    0.078694
# 11    0.092458
# 12    0.066275
# 13    0.088232
# 14    0.091959
# 15    0.075549
# 16    0.065757
# 17    0.083785
# 40    0.459985
# 41    0.481895
# 42    0.452179
# 43    0.478626
# 44    0.462345
# 45    0.465477
# 46    0.482182
# 47    0.509056
# 48    0.545667
# 49    0.515452
# 50    0.522007
# 51    0.514947
# 52    0.080239
# Name: OccupancyPercentage, dtype: float64

# %%
sns.lineplot(x=res.index, y=res, sort=False)
plt.title("Average Occupancy Percentage across Parking Lots by Week")
# Out:
# Text(0.5, 1.0, 'Average Occupancy Percentage across Parking Lots by Week')

# %%
df.head()
# Out:
#   SystemCodeNumber  Capacity  OccupancyPercentage         LastUpdated  \
# 0      BHMBCCMKT01       577             0.105719 2016-10-04 07:59:42
# 1      BHMBCCMKT01       577             0.110919 2016-10-04 08:25:42
# 2      BHMBCCMKT01       577             0.138648 2016-10-04 08:59:42
# 3      BHMBCCMKT01       577             0.185442 2016-10-04 09:32:46
# 4      BHMBCCMKT01       577             0.259965 2016-10-04 09:59:48
#
#    Occupancy  month  week  dayofweek        date  date_time_halfhour      time
# 0         61     10    40          1  2016-10-04 2016-10-04 08:00:00  08:00:00
# 1         64     10    40          1  2016-10-04 2016-10-04 08:30:00  08:30:00
# 2         80     10    40          1  2016-10-04 2016-10-04 09:00:00  09:00:00
# 3        107     10    40          1  2016-10-04 2016-10-04 09:30:00  09:30:00
# 4        150     10    40          1  2016-10-04 2016-10-04 10:00:00  10:00:00

# %% [markdown]
# **Average Occupancy by day of the week**

# %%
#View Average occupancy by day of week
res = df.groupby(["dayofweek"])["OccupancyPercentage"].mean()
print(res)
# Out:
# dayofweek
# 0    0.488189
# 1    0.512624
# 2    0.508595
# 3    0.515567
# 4    0.486824
# 5    0.396957
# 6    0.323927
# Name: OccupancyPercentage, dtype: float64

# %%
sns.lineplot(x=res.index, y=res, sort=False)
plt.title("Average Occupancy Percentage across Parking Lots by Day of the week")
# Out:
# Text(0.5, 1.0, 'Average Occupancy Percentage across Parking Lots by Day of the week')

# %% [markdown]
# **Average Occupancy by time of the day**

# %%
#View Average occupancy by time of the day
res = df.groupby(["time"])["OccupancyPercentage"].mean()
print(res)
# Out:
# time
# 08:00:00    0.204234
# 08:30:00    0.249186
# 09:00:00    0.308276
# 09:30:00    0.355040
# 10:00:00    0.406590
# 10:30:00    0.449794
# 11:00:00    0.485027
# 11:30:00    0.509595
# 12:00:00    0.534077
# 12:30:00    0.549434
# 13:00:00    0.561959
# 13:30:00    0.565823
# 14:00:00    0.572071
# 14:30:00    0.563975
# 15:00:00    0.546684
# 15:30:00    0.528826
# 16:00:00    0.499309
# 16:30:00    0.484141
# Name: OccupancyPercentage, dtype: float64

# %%
sns.lineplot(x=np.arange(start=0,stop=18,step=1), y=res, sort=False)
plt.title("Average Occupancy Percentage across Parking Lots by Time of the day")
# Out:
# Text(0.5, 1.0, 'Average Occupancy Percentage across Parking Lots by Time of the day')

# %% [markdown]
# **Average Occupancy by parking lot**

# %%
#View Average occupancy by parking lot
res = df.groupby(["SystemCodeNumber"])["OccupancyPercentage"].mean()
print(res)
# Out:
# SystemCodeNumber
# BHMBCCMKT01         0.181513
# BHMBCCPST01         0.277225
# BHMBCCSNH01         0.661667
# BHMBCCTHL01         0.683926
# BHMBRCBRG01         0.616504
# BHMBRCBRG02         0.461086
# BHMBRCBRG03         0.287760
# BHMBRTARC01         0.776645
# BHMEURBRD01         0.645510
# BHMEURBRD02         0.622427
# BHMMBMMBX01         0.695537
# BHMNCPHST01         0.467382
# BHMNCPLDH01         0.703709
# BHMNCPNHS01         0.716133
# BHMNCPNST01         0.590914
# BHMNCPPLS01         0.198652
# BHMNCPRAN01         0.649416
# Broad Street        0.633930
# Bull Ring           0.478424
# NIA Car Parks       0.163968
# NIA North           0.081491
# NIA South           0.249999
# Others-CCCPS105a    0.567590
# Others-CCCPS119a    0.193208
# Others-CCCPS133     0.472576
# Others-CCCPS135a    0.591684
# Others-CCCPS202     0.344823
# Others-CCCPS8       0.500979
# Others-CCCPS98      0.327690
# Shopping            0.556908
# Name: OccupancyPercentage, dtype: float64

# %%
plt.figure(figsize=(15,15))
plt.title("Average Occupancy Percentage across Parking Lots")
sns.barplot(x=res, y=res.index)
# Out:
# <AxesSubplot:title={'center':'Average Occupancy Percentage across Parking Lots'}, xlabel='OccupancyPercentage', ylabel='SystemCodeNumber'>

# %% [markdown]
# ## 5. Data Pre-Processing

# %% [markdown]
# ### Key Data Pre-Processing steps performed
#
# - Convert LastUpdated to Numeric
# - Create Dummy variable for SystemCodeNumber | Month | Week | Day of week
# - Extract hours and minutes from time column
# - Remove the following columns - "Capacity", "Occupancy", "date" and "date_time_halfhour"
# - Split the data into train and test data
# - Scale train and test data
# - Split X and y from train and test data respectively

# %%
def dataProcessing(df, scaler):
    
    df.set_index('LastUpdated', inplace=True)
    
    #Drop selected columns
    df = drop_col(df, ["date", "date_time_halfhour", "OccupancyPercentage"])
    
    catCols = ["SystemCodeNumber","month","week","dayofweek"]

    #Get dummy variables
    for eachCol in catCols:
        df[eachCol] = pd.factorize(df[eachCol])[0] 
        
    #Extract hours and minutes from time column
    df["time"] = df.apply(lambda x: x["time"].hour + (x["time"].minute)/60, axis=1)
    
    num_vars = ["time", "Capacity"]
    
    #Transform test data
    df[num_vars] = scaler.transform(df[num_vars])
    
    
    return df

# %% [markdown]
# **5.1 Set LastUpdated as index column**

# %%
df.set_index('LastUpdated', inplace=True)

# %% [markdown]
# **5.2 Remove unwanted columns**

# %%
#Drop selected columns
df = drop_col(df, ["date", "date_time_halfhour", "OccupancyPercentage"])

# %%
# Select categorical columns
catCols = df.select_dtypes("object").columns

# %%
catCols
# Out:
# Index(['SystemCodeNumber', 'time'], dtype='object')

# %%
df.head()
# Out:
#                     SystemCodeNumber  Capacity  Occupancy  month  week  \
# LastUpdated
# 2016-10-04 07:59:42      BHMBCCMKT01       577         61     10    40
# 2016-10-04 08:25:42      BHMBCCMKT01       577         64     10    40
# 2016-10-04 08:59:42      BHMBCCMKT01       577         80     10    40
# 2016-10-04 09:32:46      BHMBCCMKT01       577        107     10    40
# 2016-10-04 09:59:48      BHMBCCMKT01       577        150     10    40
#
#                      dayofweek      time
# LastUpdated
# 2016-10-04 07:59:42          1  08:00:00
# 2016-10-04 08:25:42          1  08:30:00
# 2016-10-04 08:59:42          1  09:00:00
# 2016-10-04 09:32:46          1  09:30:00
# 2016-10-04 09:59:48          1  10:00:00

# %% [markdown]
# **5.2 Create Dummy variable for SystemCodeNumber | Month | Week | Day of week**

# %%
catCols = ["SystemCodeNumber","month","week","dayofweek"]

# %%
#Get dummy variables
for eachCol in catCols:
    df[eachCol] = pd.factorize(df[eachCol])[0]

# %%
#Get dummy variables
# df = add_dummies(df, ["SystemCodeNumber","month","week","dayofweek"], dropx=True)

# %% [markdown]
# **5.3 Extract hours and minutes from time column**

# %%
#Extract hours and minutes from time column
df["time"] = df.apply(lambda x: x["time"].hour + (x["time"].minute)/60, axis=1)

# %% [markdown]
# **5.5 Split the data into train and test data**

# %%
#Split the train and test data
df_train, df_val = df_partitioning(df, test_size=0.3, random_state=23, shuffle=True)
print(df_train.shape)
print(df_val.shape)
# Out:
# (26160, 7)
# (11212, 7)

# %%
df_train
# Out:
#                      SystemCodeNumber  Capacity  Occupancy  month  week  \
# LastUpdated
# 2016-11-15 07:57:43                 2       863        272      1     6
# 2016-10-14 12:01:11                 1       317        176      0     1
# 2016-11-05 15:00:40                15       450        172      1     4
# 2016-10-04 09:59:48                26      2937       1163      0     0
# 2016-12-16 08:30:12                 5      1194        140      2    10
# ...                               ...       ...        ...    ...   ...
# 2016-10-22 08:59:44                 5      1194         92      0     2
# 2016-12-18 10:30:23                 8       470         99      2    10
# 2016-10-14 10:27:09                10       687        489      0     1
# 2016-11-08 15:00:02                23      2803        579      1     5
# 2016-11-21 10:04:29                 8       470        348      1     7
#
#                      dayofweek  time
# LastUpdated
# 2016-11-15 07:57:43          0   8.0
# ...

# %% [markdown]
# **5.5 Scale train and test data separately**

# %%
# Apply scaler() to all the columns except the 'yes-no' and 'dummy' variables
num_vars = ["time", "Capacity"]
# df_train, df_test = scaling(df_train, df_test, num_vars)


# Apply scaler() to all the numCols
scaler = preprocessing.MinMaxScaler()
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])
df_val[num_vars] = scaler.transform(df_val[num_vars])

# %% [markdown]
# **5.6 Split x and y from scaled train-test set**

# %%
y_train = df_train.pop('Occupancy')
X_train = df_train

# %%
y_val = df_val.pop('Occupancy')
X_val = df_val

# %%
X_train.columns
# Out:
# Index(['SystemCodeNumber', 'Capacity', 'month', 'week', 'dayofweek', 'time'], dtype='object')

# %% [markdown]
# ## 6. Model Building

# %% [markdown]
# ### 6.1 Decision Tree Regressor

# %%
#Import Decision Tree
from sklearn.tree import DecisionTreeRegressor

# %%
#Initiate the model
dt = DecisionTreeRegressor(max_depth=500,random_state=3)

# %%
#View X_train
X_train.head()
# Out:
#                      SystemCodeNumber  Capacity  month  week  dayofweek  \
# LastUpdated
# 2016-11-15 07:57:43                 2  0.018115      1     6          0
# 2016-10-14 12:01:11                 1  0.002733      0     1          3
# 2016-11-05 15:00:40                15  0.006480      1     4          4
# 2016-10-04 09:59:48                26  0.076546      0     0          0
# 2016-12-16 08:30:12                 5  0.027440      2    10          3
#
#                          time
# LastUpdated
# 2016-11-15 07:57:43  0.000000
# 2016-10-14 12:01:11  0.470588
# 2016-11-05 15:00:40  0.823529
# 2016-10-04 09:59:48  0.235294
# 2016-12-16 08:30:12  0.058824

# %%
#Fit the model
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=500, random_state=3)

# %%
#Predict test set labels
y_pred = dt.predict(X_val)

# %%
#Compute test-set MSE
mse_dt = metrics.mean_squared_error(y_val, y_pred)

# %%
#Compute test-set RMSE
rmse_dt = mse_dt**(1/2)

# %%
#Print test-set RMSE
rmse_dt
# Out:
# 129.6248354883566

# %%
#Compute train-set MSE
mse_dt_train = metrics.mean_squared_error(y_train, dt.predict(X_train))

# %%
#Compute train-set RMSE
rmse_dt_train = mse_dt_train**(1/2)

# %%
#Print train-set RMSE 
rmse_dt_train
# Out:
# 0.4071465935309458

# %% [markdown]
# **K-Fold Cross Validation**

# %%
# Compute the array containing the 10-folds CV MSEs
MSE_CV_scores = - model_selection.cross_val_score(dt, X_train, y_train, cv=10, 
                                  scoring='neg_mean_squared_error', 
                                  n_jobs=-1) 

# Compute the 10-folds CV RMSE
RMSE_CV = (MSE_CV_scores.mean())**(1/2)

# Print RMSE_CV
print('CV RMSE: {:.2f}'.format(RMSE_CV))
# Out:
# CV RMSE: 139.55

# %% [markdown]
# **R2 Score**

# %%
#Calculate R2 Score on the training set
metrics.r2_score(y_train, dt.predict(X_train))
# Out:
# 0.9999996065661998

# %%
#Calculate R2 Score on the test set
metrics.r2_score(y_val, y_pred)
# Out:
# 0.9600460031520387

# %%
#Plot test set output and predictions - As expected, the scatterplot is linear
plt.title("Y-val vs Y-Pred")
plt.xlabel("Y-Val")
plt.ylabel("Y-Pred") 
sns.scatterplot(x=y_val, y=y_pred)
# Out:
# <AxesSubplot:title={'center':'Y-val vs Y-Pred'}, xlabel='Y-Val', ylabel='Y-Pred'>

# %%
#Calculate abs error value
abs_error = np.abs(y_val - y_pred)

# %%
#Plot absolute error
plt.title("Occupancy vs Absolute Error")
plt.xlabel("Occupancy")
plt.ylabel("Absolute Error") 
ax = sns.scatterplot(x=y_val, y=abs_error)

# %% [markdown]
# ### 6.2 Random Forest Regressor

# %%
# Import RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor

# Instantiate rf
rf = RandomForestRegressor(n_estimators=50, random_state=2)
                           
# Fit rf to the training set            
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=2)

# %%
# Import mean_squared_error as MSE
from sklearn.metrics import mean_squared_error as MSE

# Predict the test set labels
y_pred = rf.predict(X_val)

# Evaluate the test set RMSE
rmse_test = MSE(y_val, y_pred)**(1/2)

# Print rmse_test
print('Test set RMSE of rf: {:.2f}'.format(rmse_test))
# Out:
# Test set RMSE of rf: 101.21

# %%
#R2 Score on the training set
metrics.r2_score(y_train, rf.predict(X_train))
# Out:
# 0.9964330569443713

# %%
#R2 Score on the test set
metrics.r2_score(y_val, y_pred)
# Out:
# 0.9756444468483598

# %%
plt.title("Y-val vs Y-Pred")
plt.xlabel("Y-Val")
plt.ylabel("Y-Pred")
ax = sns.scatterplot(x=y_val, y=y_pred)

# %%
abs_error = np.abs(y_val - y_pred)

# %%
plt.title("Occupancy vs Absolute Error")
plt.xlabel("Occupancy")
plt.ylabel("Absolute Error") 
ax = sns.scatterplot(x=y_val, y=abs_error)

# %%
# Create a pd.Series of features importances
importances = pd.Series(data=rf.feature_importances_,
                        index= X_train.columns)

# Sort importances
importances_sorted = importances.sort_values()

# Draw a horizontal barplot of importances_sorted
importances_sorted.plot(kind='barh', color='lightgreen')
plt.title('Features Importances')
plt.show()

# %% [markdown]
# # 7. Test Set Predictions

# %%
#Load the dataset
df_test = pd.read_csv('dataset/test.csv')
df_test.shape
# Out:
# (1039, 7)

# %%
#Clean the test dataset
df_test = dataCleaning(df_test)

# %%
#Process the test dataset
df_test = dataProcessing(df_test, scaler)

# %%
test_pred = rf.predict(df_test)

# %%
#Creating Output dataframe
data = {"LastUpdated": df_test.index, 
        "Occupancy": test_pred
       }

submission = pd.DataFrame(data)

# %%
submission.to_csv("submission.csv",index=False)
